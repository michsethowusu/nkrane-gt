# %%
pip install -e .
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Obtaining file:///home/owusus/Documents/GitHub/nkrane
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# ...
#   Using cached googletrans-4.0.0rc1-py3-none-any.whl
# ...
#   Using cached httpx-0.13.3-py3-none-any.whl.metadata (25 kB)
# ...
#   Using cached httpcore-0.9.1-py3-none-any.whl.metadata (4.6 kB)
# ...
#   Using cached h11-0.9.0-py2.py3-none-any.whl.metadata (8.1 kB)
# ...
# Using cached httpx-0.13.3-py3-none-any.whl (55 kB)
# Using cached httpcore-0.9.1-py3-none-any.whl (42 kB)
# Using cached h11-0.9.0-py2.py3-none-any.whl (53 kB)
# ...
#   Building editable for nkrane-gt (pyproject.toml) ... done
#   Created wheel for nkrane-gt: filename=nkrane_gt-0.2.0-0.editable-py3-none-any.whl size=4921 sha256=1cdc2b85454790efee4c4498d702a67eace3432712f19230bcc336411877846f
# ...

# %%
from nkrane_gt import NkraneTranslator

# With built-in dictionary only
translator1 = NkraneTranslator(target_lang='ak')
result1 = translator1.translate("I want to buy a house and a car.")

# With built-in + user dictionary
#translator2 = NkraneTranslator(
#    target_lang='ak',
#    terminology_source='my_terms.csv'
#)

# Without built-in (only user dictionary)
#translator3 = NkraneTranslator(
#    target_lang='ak',
    #terminology_source='my_terms.csv',
 #   use_builtin=False
#)
# Out:
# Loaded 446281 built-in terms for ak
# INFO:nkrane_gt.translator:Terminology loaded: 446281 total terms (446281 built-in, 0 user)

# %%
cd nkrane
# Out:
# [Errno 2] No such file or directory: 'nkrane'
# /home/owusus/Documents/GitHub/nkrane

# %%
from nkrane_gt import NkraneTranslator

translator1 = NkraneTranslator(target_lang='ak')
result1 = translator1.translate("Joy FM is a privately owned radio station in Accra, the capital of Ghana. The station is owned and run by the media group company Multimedia Group Limited.")

# Option 1: Print just the translated text
print(result1['text'])

# Option 2: Print the full result dictionary nicely
import json
print(json.dumps(result1, indent=2, ensure_ascii=False))

# Option 3: Just put result1 at the end (Jupyter will display it)
result1
# Out:
# Loaded 446281 built-in terms for ak
# INFO:nkrane_gt.translator:Terminology loaded: 446281 total terms (446281 built-in, 0 user)
# Joy FM yɛ ankorankoro radio dwumadibea a ɛwɔ Accra, Ghana ahenkurow. Gyinabea no yɛ nsɛm ho amanneɛbɔ kuw Multimedia Group Limited dea na ɛhwɛ so.
# {
#   "text": "Joy FM yɛ ankorankoro radio dwumadibea a ɛwɔ Accra, Ghana ahenkurow. Gyinabea no yɛ nsɛm ho amanneɛbɔ kuw Multimedia Group Limited dea na ɛhwɛ so.",
#   "src": "en",
#   "dest": "ak",
#   "original": "Joy FM is a privately owned radio station in Accra, the capital of Ghana. The station is owned and run by the media group company Multimedia Group Limited.",
#   "preprocessed": "Joy FM is a privately owned radio station in Accra, the capital of Ghana. The <1> is owned and run by the media group company Multimedia Group Limited.",
# ...
